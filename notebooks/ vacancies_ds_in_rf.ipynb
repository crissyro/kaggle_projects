# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
PATH = 'data/hh_vacancies.json'
df = pd.read_json(PATH)
df
# Out:
#             id  premium                                               name  \
# 0    112388836    False                     Junior Data Scientist (Стажер)
# 1    112331201    False                                     Data scientist
# 2    112715627    False  ML-разработчик / Data Scientist (Intern / Juni...
# 3    112611475    False  Data Scientist / Machine Learning Engineer / А...
# 4    112578650    False                                     Data scientist
# ..         ...      ...                                                ...
# 433  106073007    False                   Senior Data Scientist (GigaCode)
# 434  106528974    False                          Senior Python разработчик
# 435  110976109    False                        Devops инженер на ML проект
# 436   95077714    False                    Data Scientist (команда Поиска)
# 437  107198493    False            Senior Data Scientist в b2c направление
#
#                                             department  has_test  \
# ...

# %%
df = df.dropna(axis=1)
df
# Out:
#             id  premium                                               name  \
# 0    112388836    False                     Junior Data Scientist (Стажер)
# 1    112331201    False                                     Data scientist
# 2    112715627    False  ML-разработчик / Data Scientist (Intern / Juni...
# 3    112611475    False  Data Scientist / Machine Learning Engineer / А...
# 4    112578650    False                                     Data scientist
# ..         ...      ...                                                ...
# 433  106073007    False                   Senior Data Scientist (GigaCode)
# 434  106528974    False                          Senior Python разработчик
# 435  110976109    False                        Devops инженер на ML проект
# 436   95077714    False                    Data Scientist (команда Поиска)
# 437  107198493    False            Senior Data Scientist в b2c направление
#
#      has_test  response_letter_required  \
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 438 entries, 0 to 437
# Data columns (total 26 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   id                         438 non-null    int64
#  1   premium                    438 non-null    bool
#  2   name                       438 non-null    object
#  3   has_test                   438 non-null    bool
#  4   response_letter_required   438 non-null    bool
#  5   area                       438 non-null    object
#  6   type                       438 non-null    object
#  7   published_at               438 non-null    datetime64[ns, UTC+03:00]
#  8   created_at                 438 non-null    datetime64[ns, UTC+03:00]
#  9   archived                   438 non-null    bool
#  10  apply_alternate_url        438 non-null    object
#  11  url                        438 non-null    object
#  12  alternate_url              438 non-null    object
# ...

# %%
df = df.drop(columns=
             ['type', 'premium', 'published_at', 'created_at', 'archived', 
              'apply_alternate_url', 'url', 'alternate_url', 'working_days', 
              'working_time_intervals', 'working_time_modes', 'is_adv_vacancy', 
              'relations', 'employer', 'id']
             )
df
# Out:
#                                                   name  has_test  \
# 0                       Junior Data Scientist (Стажер)     False
# 1                                       Data scientist     False
# 2    ML-разработчик / Data Scientist (Intern / Juni...     False
# 3    Data Scientist / Machine Learning Engineer / А...     False
# 4                                       Data scientist     False
# ..                                                 ...       ...
# 433                   Senior Data Scientist (GigaCode)     False
# 434                          Senior Python разработчик     False
# 435                        Devops инженер на ML проект     False
# 436                    Data Scientist (команда Поиска)     False
# 437            Senior Data Scientist в b2c направление     False
#
#      response_letter_required  \
# 0                       False
# 1                       False
# 2                       False
# 3                       False
# ...

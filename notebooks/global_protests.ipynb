# %% [markdown]
# # Global Protests from 1990 to March 2020 analysis

# %%
# import kagglehub

# Download latest version
# path = kagglehub.dataset_download("mysterymeatie/protests-from-1990-to-march-2020")

# print("Path to dataset files:", path)

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns 
import plotly.express as px
import plotly.graph_objects as go
from plotly.offline import init_notebook_mode, iplot 
import warnings

init_notebook_mode(connected=True)
warnings.filterwarnings('ignore')
plt.style.use('seaborn-v0_8-pastel')
sns.set_theme(style='whitegrid')
# Out:
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         if (typeof require !== 'undefined') {
#         require.undef("plotly");
#         requirejs.config({
#             paths: {
#                 'plotly': ['https://cdn.plot.ly/plotly-2.35.2.min']
#             }
#         });
#         require(['plotly'], function(Plotly) {
#             window._Plotly = Plotly;
#         });
#         }
#         </script>

# %%
df = pd.read_csv('data/global_protests.csv', sep=',')
print(df.shape)
df.head()
# Out:
# (12652, 25)
#           id Country  Year         region  protest  protesterviolence  \
# 0  201990001  Canada  1990  North America        1                  0
# 1  201990002  Canada  1990  North America        1                  0
# 2  201990003  Canada  1990  North America        1                  0
# 3  201990004  Canada  1990  North America        1                  1
# 4  201990005  Canada  1990  North America        1                  1
#
#               protesterdemand1    protesterdemand2 protesterdemand3  \
# 0  political behavior, process  labor wage dispute              NaN
# 1  political behavior, process                 NaN              NaN
# 2  political behavior, process                 NaN              NaN
# 3              land farm issue                 NaN              NaN
# 4  political behavior, process                 NaN              NaN
#
#   protesterdemand4  ... stateresponse6 stateresponse7 Electoral_Score  \
# 0              NaN  ...            NaN            NaN           0.834
# 1              NaN  ...            NaN            NaN           0.834
# 2              NaN  ...            NaN            NaN           0.834
# 3              NaN  ...            NaN            NaN           0.834
# 4              NaN  ...            NaN            NaN           0.834
#
#   Liberal_Score Participatory_Score Deliberative_Score Egalitarian_Score  \
# 0         0.759                0.58              0.756             0.719
# 1         0.759                0.58              0.756             0.719
# 2         0.759                0.58              0.756             0.719
# 3         0.759                0.58              0.756             0.719
# 4         0.759                0.58              0.756             0.719
#
#    HDI_Score  violenceStatus  predicted_prob
# 0       0.85               0        0.299385
# 1       0.85               0        0.299385
# 2       0.85               0        0.299385
# 3       0.85               1        0.299385
# 4       0.85               1        0.299385
#
# [5 rows x 25 columns]

# %% [markdown]
# ## Dataset Card:
#
# 1. id: Unique ID for each protest event
#
# 2. Country: Country that the protest occurred in
#
# 3. Year: Year that the protest occurred in
#
# 4. region: Continent that the protest occurred in
#
# 5. protest: Whether or not this event was a protest (value = 1 for all).
#
# 6. protesterviolence: Whether or not protesters engaged in violence (The violence
# could include anything from riotous behavior that destroys property to shooting at the police or military.)
#
# 7. protesterdemand1: A slot for protesters' demand to be coded (view Mass Mobilization codebook for explanation)
#
# 8. protesterdemand2: See above
#
# 9. protesterdemand3: See above
#
# 10. protesterdemand4: See above
#
# 11. stateresponse1: A slot for state's response to be coded (view Mass Mobilization codebook for explanation)
#
# 12. stateresponse2: See above
#
# 13. stateresponse3: See above
#
# 14. stateresponse4: See above
#
# 15. stateresponse5: See above
#
# 16. stateresponse6: See above
#
# 17. stateresponse7: See above
#
# 18. Electoral_Score: A score of democracy in the electoral aspect for the country and year specific to the protest event
#
# 19. Liberal_Score: A score of democracy in the electoral aspect for the country and year specific to the protest event
#
# 20. Participatory_Score: A score of democracy in the electoral aspect for the country and year specific to the protest event
#
# 21. Deliberative_Score: A score of democracy in the electoral aspect for the country and year specific to the protest event
#
# 22. Egalitarian_Score: A score of democracy in the electoral aspect for the country and year specific to the protest event
#
# 23. HDI_Score: Human Development Index score for the country and year specific to the protest event
# violenceStatus: Whether or not the protest was violent.
#
# * (For violentStatus = 1 [protest was violent], protesterviolence == 1 OR any of stateresponse1-7 coded ['arrests', 'beatings', crowd dispersal', 'shootings', 'killings'])
#
# * (For violentStatus = 0 [protest was nonviolent], protesterviolence == 0 AND NONE of stateresponse1-7 can be coded ['arrests', 'beatings', crowd dispersal', 'shootings', 'killings'])
#
# 24. predicted_prob: Probability of the protest being successful or not produced by logistic regression model trained on the 5 democracy scores and HDI score. Successful == 'accomodation' in ANY of stateresponse1-7 columns.

# %%
df.isnull().sum()
# Out:
# id                         0
# Country                    0
# Year                       0
# region                     0
# protest                    0
# protesterviolence          0
# protesterdemand1           1
# protesterdemand2       10091
# protesterdemand3       12317
# protesterdemand4       12011
# stateresponse1            23
# stateresponse2         10280
# stateresponse3         11896
# stateresponse4         12453
# stateresponse5         11995
# stateresponse6         12639
# stateresponse7         11893
# Electoral_Score            0
# Liberal_Score              0
# Participatory_Score        0
# Deliberative_Score         0
# Egalitarian_Score          0
# HDI_Score                216
# violenceStatus             0
# predicted_prob           216
# dtype: int64

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 12652 entries, 0 to 12651
# Data columns (total 25 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   id                   12652 non-null  int64
#  1   Country              12652 non-null  object
#  2   Year                 12652 non-null  int64
#  3   region               12652 non-null  object
#  4   protest              12652 non-null  int64
#  5   protesterviolence    12652 non-null  int64
#  6   protesterdemand1     12651 non-null  object
#  7   protesterdemand2     2561 non-null   object
#  8   protesterdemand3     335 non-null    object
#  9   protesterdemand4     641 non-null    object
#  10  stateresponse1       12629 non-null  object
#  11  stateresponse2       2372 non-null   object
#  12  stateresponse3       756 non-null    object
#  13  stateresponse4       199 non-null    object
#  14  stateresponse5       657 non-null    object
#  15  stateresponse6       13 non-null     object
#  16  stateresponse7       759 non-null    object
#  17  Electoral_Score      12652 non-null  float64
#  18  Liberal_Score        12652 non-null  float64
#  19  Participatory_Score  12652 non-null  float64
#  20  Deliberative_Score   12652 non-null  float64
#  21  Egalitarian_Score    12652 non-null  float64
#  22  HDI_Score            12436 non-null  float64
#  23  violenceStatus       12652 non-null  int64
#  24  predicted_prob       12436 non-null  float64
# dtypes: float64(7), int64(5), object(13)
# memory usage: 2.4+ MB

# %%
df.describe()
# Out:
#                  id          Year  protest  protesterviolence  \
# count  1.265200e+04  12652.000000  12652.0       12652.000000
# mean   4.263609e+09   2006.626620      1.0           0.263990
# std    2.363909e+09      8.812148      0.0           0.440811
# min    2.019900e+08   1990.000000      1.0           0.000000
# 25%    2.052018e+09   1999.000000      1.0           0.000000
# 50%    3.732010e+09   2008.000000      1.0           0.000000
# 75%    6.452011e+09   2014.000000      1.0           1.000000
# max    9.102017e+09   2019.000000      1.0           1.000000
#
#        Electoral_Score  Liberal_Score  Participatory_Score  \
# count     12652.000000   12652.000000         12652.000000
# mean          0.566069       0.446735             0.370286
# std           0.251981       0.269327             0.201592
# min           0.014000       0.006000             0.009000
# 25%           0.352000       0.211000             0.203000
# 50%           0.549000       0.403000             0.346000
# 75%           0.843000       0.755000             0.582000
# max           0.922000       0.896000             0.807000
#
#        Deliberative_Score  Egalitarian_Score     HDI_Score  violenceStatus  \
# count        12652.000000       12652.000000  12436.000000    12652.000000
# mean             0.455604           0.420957      0.679471        0.440642
# std              0.251682           0.246582      0.161842        0.496484
# min              0.006000           0.034000      0.197000        0.000000
# 25%              0.241000           0.213000      0.558000        0.000000
# 50%              0.415000           0.331000      0.694000        0.000000
# 75%              0.727000           0.680000      0.807000        1.000000
# max              0.886000           0.885000      0.955000        1.000000
#
#        predicted_prob
# count    12436.000000
# mean         0.439530
# std          0.125796
# min          0.237938
# 25%          0.309645
# 50%          0.455389
# 75%          0.539201
# max          0.775399

# %%
df = df.drop(['id', 'protest', 'protesterdemand2', 'protesterdemand3',
         'protesterdemand4', 'stateresponse2', 'stateresponse3',
         'stateresponse4', 'stateresponse5', 'stateresponse6',
         'stateresponse7'], 
        axis=1)

# %%
df.isnull().sum()
# Out:
# Country                  0
# Year                     0
# region                   0
# protesterviolence        0
# protesterdemand1         1
# stateresponse1          23
# Electoral_Score          0
# Liberal_Score            0
# Participatory_Score      0
# Deliberative_Score       0
# Egalitarian_Score        0
# HDI_Score              216
# violenceStatus           0
# predicted_prob         216
# dtype: int64

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 12652 entries, 0 to 12651
# Data columns (total 14 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   Country              12652 non-null  object
#  1   Year                 12652 non-null  int64
#  2   region               12652 non-null  object
#  3   protesterviolence    12652 non-null  int64
#  4   protesterdemand1     12651 non-null  object
#  5   stateresponse1       12629 non-null  object
#  6   Electoral_Score      12652 non-null  float64
#  7   Liberal_Score        12652 non-null  float64
#  8   Participatory_Score  12652 non-null  float64
#  9   Deliberative_Score   12652 non-null  float64
#  10  Egalitarian_Score    12652 non-null  float64
#  11  HDI_Score            12436 non-null  float64
#  12  violenceStatus       12652 non-null  int64
#  13  predicted_prob       12436 non-null  float64
# dtypes: float64(7), int64(3), object(4)
# memory usage: 1.4+ MB

# %%
df.dropna(subset=['stateresponse1', 'protesterdemand1'], inplace=True)

df['predicted_prob'].fillna(df['predicted_prob'].mean(), inplace=True)
df['HDI_Score'].fillna(df['HDI_Score'].mean(), inplace=True)

# %%
df.isnull().sum()
# Out:
# Country                0
# Year                   0
# region                 0
# protesterviolence      0
# protesterdemand1       0
# stateresponse1         0
# Electoral_Score        0
# Liberal_Score          0
# Participatory_Score    0
# Deliberative_Score     0
# Egalitarian_Score      0
# HDI_Score              0
# violenceStatus         0
# predicted_prob         0
# dtype: int64

# %%
df.head()
# Out:
#   Country  Year         region  protesterviolence  \
# 0  Canada  1990  North America                  0
# 1  Canada  1990  North America                  0
# 2  Canada  1990  North America                  0
# 3  Canada  1990  North America                  1
# 4  Canada  1990  North America                  1
#
#               protesterdemand1   stateresponse1  Electoral_Score  \
# 0  political behavior, process           ignore            0.834
# 1  political behavior, process           ignore            0.834
# 2  political behavior, process           ignore            0.834
# 3              land farm issue     accomodation            0.834
# 4  political behavior, process  crowd dispersal            0.834
#
#    Liberal_Score  Participatory_Score  Deliberative_Score  Egalitarian_Score  \
# 0          0.759                 0.58               0.756              0.719
# 1          0.759                 0.58               0.756              0.719
# 2          0.759                 0.58               0.756              0.719
# 3          0.759                 0.58               0.756              0.719
# 4          0.759                 0.58               0.756              0.719
#
#    HDI_Score  violenceStatus  predicted_prob
# 0       0.85               0        0.299385
# 1       0.85               0        0.299385
# 2       0.85               0        0.299385
# 3       0.85               1        0.299385
# 4       0.85               1        0.299385

# %%
cnt_country = df['Country'].value_counts().reset_index()
cnt_country = cnt_country[cnt_country['count'] >= 50]

fig = px.bar(data_frame=cnt_country, x='Country', y='count')

iplot(fig)
# Out:
# <div>                            <div id="599d7014-f3fc-49e9-a69e-88f9acb0513d" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("599d7014-f3fc-49e9-a69e-88f9acb0513d")) {                    Plotly.newPlot(                        "599d7014-f3fc-49e9-a69e-88f9acb0513d",                        [{"alignmentgroup":"True","hovertemplate":"Country=%{x}\u003cbr\u003ecount=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"","offsetgroup":"","orientation":"v","showlegend":false,"textposition":"auto","x":["United Kingdom","France","Ireland","Germany","Kenya","Bangladesh","China","Greece","Thailand","Namibia","Brazil","India","Romania","Nepal","South Africa","Pakistan","Chile","Spain","Italy","Nigeria","Peru","Kyrgyzstan","Ecuador","Yemen","Indonesia","Mexico","Ukraine","Malaysia","Colombia","Cyprus","Egypt","Azerbaijan","Bulgaria","Iraq","Poland","Haiti","Lebanon","Zimbabwe","Honduras","Argentina","Madagascar","Guatemala","Niger","Algeria","Armenia","Guinea","Cuba","Burundi","Zambia","Togo","Nicaragua","Kazakhstan","Latvia","Mauritania","Comoros","Albania","Mozambique","Sri Lanka","Hungary","Belarus","Dominican Republic","Uruguay","Liberia","Burkina Faso","Paraguay","Ghana","Malawi","Sudan","Philippines","Uganda","Central African Republic","Benin","Georgia","Cameroon","Japan","Mali","Cambodia","Canada","Suriname","Mongolia","El Salvador"],"xaxis":"x","y":[574,541,431,362,350,338,316,311,249,225,223,221,219,210,175,175,171,167,166,164,163,161,161,157,152,150,148,147,139,128,126,125,124,122,122,122,121,115,113,113,111,111,106,105,104,100,99,98,95,94,89,85,85,81,80,77,75,74,71,71,69,68,68,67,66,65,64,64,64,63,61,59,59,58,58,53,53,52,51,50,50],"yaxis":"y","type":"bar"}],                        {"barmode":"relative","legend":{"tracegroupgap":0},"margin":{"t":60},"template":{"data":{"barpolar":[{"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"barpolar"}],"bar":[{"error_x":{"color":"#2a3f5f"},"error_y":{"color":"#2a3f5f"},"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"bar"}],"carpet":[{"aaxis":{"endlinecolor":"#2a3f5f","gridcolor":"white","linecolor":"white","minorgridcolor":"white","startlinecolor":"#2a3f5f"},"baxis":{"endlinecolor":"#2a3f5f","gridcolor":"white","linecolor":"white","minorgridcolor":"white","startlinecolor":"#2a3f5f"},"type":"carpet"}],"choropleth":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"choropleth"}],"contourcarpet":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"contourcarpet"}],"contour":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"contour"}],"heatmapgl":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"heatmapgl"}],"heatmap":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"heatmap"}],"histogram ...

# %%
df = df[df['Country'].isin(cnt_country['Country'])]
df
# Out:
#          Country  Year         region  protesterviolence  \
# 0         Canada  1990  North America                  0
# 1         Canada  1990  North America                  0
# 2         Canada  1990  North America                  0
# 3         Canada  1990  North America                  1
# 4         Canada  1990  North America                  1
# ...          ...   ...            ...                ...
# 12609  Indonesia  2019           Asia                  1
# 12610  Indonesia  2019           Asia                  1
# 12611  Indonesia  2019           Asia                  1
# 12612  Indonesia  2019           Asia                  0
# 12613  Indonesia  2019           Asia                  1
#
#                   protesterdemand1   stateresponse1  Electoral_Score  \
# 0      political behavior, process           ignore            0.834
# 1      political behavior, process           ignore            0.834
# 2      political behavior, process           ignore            0.834
# 3                  land farm issue     accomodation            0.834
# 4      political behavior, process  crowd dispersal            0.834
# ...                            ...              ...              ...
# 12609  political behavior, process         killings            0.601
# 12610             police brutality           ignore            0.601
# 12611  political behavior, process         killings            0.601
# 12612  political behavior, process  crowd dispersal            0.601
# 12613  political behavior, process  crowd dispersal            0.601
#
#        Liberal_Score  Participatory_Score  Deliberative_Score  \
# 0              0.759                0.580               0.756
# 1              0.759                0.580               0.756
# 2              0.759                0.580               0.756
# 3              0.759                0.580               0.756
# 4              0.759                0.580               0.756
# ...              ...                  ...                 ...
# 12609          0.462                0.398               0.516
# 12610          0.462                0.398               0.516
# 12611          0.462                0.398               0.516
# 12612          0.462                0.398               0.516
# 12613          0.462                0.398               0.516
#
#        Egalitarian_Score  HDI_Score  violenceStatus  predicted_prob
# 0                  0.719      0.850               0        0.299385
# 1                  0.719      0.850               0        0.299385
# 2                  0.719      0.850               0        0.299385
# 3                  0.719      0.850               1        0.299385
# 4                  0.719      0.850               1        0.299385
# ...                  ...        ...             ...             ...
# 12609              0.359      0.718               1        0.423313
# 12610              0.359      0.718               1        0.423313
# 12611              0.359      0.718               1        0.423313
# 12612              0.359      0.718               1        0.423313
# 12613              0.359      0.718               1        0.423313
#
# [11370 rows x 14 columns]

# %%
gr = df.groupby(['Country', 'Year'])['Country'].size().reset_index(name='Count')
gr
# Out:
#        Country  Year  Count
# 0      Albania  1990      5
# 1      Albania  1991      8
# 2      Albania  1992      3
# 3      Albania  1993      2
# 4      Albania  1994      1
# ...        ...   ...    ...
# 1887  Zimbabwe  2015      3
# 1888  Zimbabwe  2016     17
# 1889  Zimbabwe  2017      5
# 1890  Zimbabwe  2018      5
# 1891  Zimbabwe  2019     10
#
# [1892 rows x 3 columns]

# %%
fig = px.bar(gr, x='Country', y='Count', color='Country',
             animation_frame='Year',
             range_y=[0, gr['Count'].max() + 5],
             template='ggplot2')
fig.update_layout(width=1200, height=800)
iplot(fig)
# Out:
# <div>                            <div id="4b1dbb2a-f695-4cdb-a4c5-3262ba8bbc9c" class="plotly-graph-div" style="height:800px; width:1200px;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("4b1dbb2a-f695-4cdb-a4c5-3262ba8bbc9c")) {                    Plotly.newPlot(                        "4b1dbb2a-f695-4cdb-a4c5-3262ba8bbc9c",                        [{"alignmentgroup":"True","hovertemplate":"Country=%{x}\u003cbr\u003eYear=1990\u003cbr\u003eCount=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Albania","marker":{"color":"#F8766D","pattern":{"shape":""}},"name":"Albania","offsetgroup":"Albania","orientation":"v","showlegend":true,"textposition":"auto","x":["Albania"],"xaxis":"x","y":[5],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Country=%{x}\u003cbr\u003eYear=1990\u003cbr\u003eCount=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Algeria","marker":{"color":"#A3A500","pattern":{"shape":""}},"name":"Algeria","offsetgroup":"Algeria","orientation":"v","showlegend":true,"textposition":"auto","x":["Algeria"],"xaxis":"x","y":[2],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Country=%{x}\u003cbr\u003eYear=1990\u003cbr\u003eCount=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Argentina","marker":{"color":"#00BF7D","pattern":{"shape":""}},"name":"Argentina","offsetgroup":"Argentina","orientation":"v","showlegend":true,"textposition":"auto","x":["Argentina"],"xaxis":"x","y":[8],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Country=%{x}\u003cbr\u003eYear=1990\u003cbr\u003eCount=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Armenia","marker":{"color":"#00B0F6","pattern":{"shape":""}},"name":"Armenia","offsetgroup":"Armenia","orientation":"v","showlegend":true,"textposition":"auto","x":["Armenia"],"xaxis":"x","y":[1],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Country=%{x}\u003cbr\u003eYear=1990\u003cbr\u003eCount=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Bangladesh","marker":{"color":"#F8766D","pattern":{"shape":""}},"name":"Bangladesh","offsetgroup":"Bangladesh","orientation":"v","showlegend":true,"textposition":"auto","x":["Bangladesh"],"xaxis":"x","y":[10],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Country=%{x}\u003cbr\u003eYear=1990\u003cbr\u003eCount=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Benin","marker":{"color":"#00BF7D","pattern":{"shape":""}},"name":"Benin","offsetgroup":"Benin","orientation":"v","showlegend":true,"textposition":"auto","x":["Benin"],"xaxis":"x","y":[1],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Country=%{x}\u003cbr\u003eYear=1990\u003cbr\u003eCount=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Brazil","marker":{"color":"#00B0F6","pattern":{"shape":""}},"name":"Brazil","offsetgroup":"Brazil","orientation":"v","showlegend":true,"textposition":"auto","x":["Brazil"],"xaxis":"x","y":[5],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Country=%{x}\u003cbr\u003eYear=1990\u003cbr\u003eCount=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Bulgaria","marker":{"color":"#E76BF3","pattern":{"shape":""}},"name":"Bulgaria","offsetgroup":"Bulgaria","orientation":"v","showlegend":true,"textposition":"auto","x":["Bulgaria"],"xaxis":"x","y":[35],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Country=%{x}\u003cbr\u003eYear=1990\u003cbr\u003eCount=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Cameroon","marker":{"color":"#00B0F6","pattern":{"shape":""}},"name":"Cameroon","offsetgroup":"Cameroon","orientation":"v","showlegend":true,"textposition":"auto","x":["Cameroon"],"xaxis":"x","y":[2],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hov ...

# %%
mean_in_country = gr.groupby('Country')['Count'].mean().reset_index()
mean_in_country
# Out:
#            Country      Count
# 0          Albania   5.133333
# 1          Algeria   7.500000
# 2        Argentina   4.185185
# 3          Armenia   3.851852
# 4       Azerbaijan   5.434783
# ..             ...        ...
# 76  United Kingdom  19.133333
# 77         Uruguay   3.090909
# 78           Yemen   7.136364
# 79          Zambia   3.518519
# 80        Zimbabwe   4.259259
#
# [81 rows x 2 columns]

# %%
fig = px.bar(data_frame=mean_in_country, x='Country', y='Count')
iplot(fig)
# Out:
# <div>                            <div id="774618e9-53ac-411f-a5b9-186438136d95" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("774618e9-53ac-411f-a5b9-186438136d95")) {                    Plotly.newPlot(                        "774618e9-53ac-411f-a5b9-186438136d95",                        [{"alignmentgroup":"True","hovertemplate":"Country=%{x}\u003cbr\u003eCount=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"","offsetgroup":"","orientation":"v","showlegend":false,"textposition":"auto","x":["Albania","Algeria","Argentina","Armenia","Azerbaijan","Bangladesh","Belarus","Benin","Brazil","Bulgaria","Burkina Faso","Burundi","Cambodia","Cameroon","Canada","Central African Republic","Chile","China","Colombia","Comoros","Cuba","Cyprus","Dominican Republic","Ecuador","Egypt","El Salvador","France","Georgia","Germany","Ghana","Greece","Guatemala","Guinea","Haiti","Honduras","Hungary","India","Indonesia","Iraq","Ireland","Italy","Japan","Kazakhstan","Kenya","Kyrgyzstan","Latvia","Lebanon","Liberia","Madagascar","Malawi","Malaysia","Mali","Mauritania","Mexico","Mongolia","Mozambique","Namibia","Nepal","Nicaragua","Niger","Nigeria","Pakistan","Paraguay","Peru","Philippines","Poland","Romania","South Africa","Spain","Sri Lanka","Sudan","Suriname","Thailand","Togo","Uganda","Ukraine","United Kingdom","Uruguay","Yemen","Zambia","Zimbabwe"],"xaxis":"x","y":[5.133333333333334,7.5,4.185185185185185,3.8518518518518516,5.434782608695652,12.518518518518519,3.380952380952381,3.1052631578947367,7.433333333333334,5.391304347826087,3.7222222222222223,5.157894736842105,2.789473684210526,3.0526315789473686,2.260869565217391,2.652173913043478,5.7,11.285714285714286,4.793103448275862,4.2105263157894735,12.375,7.111111111111111,3.8333333333333335,5.75,6.3,2.9411764705882355,18.033333333333335,2.5652173913043477,12.066666666666666,3.25,10.366666666666667,4.44,5.2631578947368425,4.206896551724138,4.035714285714286,3.0869565217391304,7.620689655172414,5.066666666666666,5.545454545454546,17.958333333333332,5.724137931034483,3.0526315789473686,3.4,12.5,7.666666666666667,5.0,5.761904761904762,3.090909090909091,5.55,2.782608695652174,5.653846153846154,2.65,3.857142857142857,5.0,2.7777777777777777,3.125,10.227272727272727,7.241379310344827,3.2962962962962963,4.608695652173913,7.809523809523809,6.0344827586206895,2.64,5.433333333333334,2.782608695652174,4.6923076923076925,9.125,6.0344827586206895,5.964285714285714,3.5238095238095237,5.818181818181818,3.0,9.222222222222221,4.086956521739131,3.0,7.4,19.133333333333333,3.090909090909091,7.136363636363637,3.5185185185185186,4.2592592592592595],"yaxis":"y","type":"bar"}],                        {"barmode":"relative","legend":{"tracegroupgap":0},"margin":{"t":60},"template":{"data":{"barpolar":[{"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"barpolar"}],"bar":[{"error_x":{"color":"#2a3f5f"},"error_y":{"color":"#2a3f5f"},"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"bar"}],"carpet":[{"aaxis":{"endlinecolor":"#2a3f5f","gridcolor":"white","linecolor":"white","minorgridcolor":"white","startlinecolor":"#2a3f5f"},"baxis":{"endlinecolor":"#2a3f5f","gridcolor":"white","linecolor":"white","minorgridcolor":"white","startlinecolor":"#2a3f5f"},"type":"carpet"}],"choropleth":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"choropleth"}],"contourcarpet":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"contourcarpet"}],"contour":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c17 ...

# %% [markdown]
# ## Split Regions

# %%
gr = df.groupby('region')['region'].size().reset_index(name='count')
gr
# Out:
#             region  count
# 0           Africa   2427
# 1             Asia   2353
# 2  Central America    363
# 3           Europe   3885
# 4             MENA    695
# 5    North America    492
# 6    South America   1155

# %%
fig = px.pie(gr, values='count', names='region', title='Region Protests Distribution')
iplot(fig)
# Out:
# <div>                            <div id="24e876b5-0c5a-43ec-ac9b-c5610b1c3f32" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("24e876b5-0c5a-43ec-ac9b-c5610b1c3f32")) {                    Plotly.newPlot(                        "24e876b5-0c5a-43ec-ac9b-c5610b1c3f32",                        [{"domain":{"x":[0.0,1.0],"y":[0.0,1.0]},"hovertemplate":"region=%{label}\u003cbr\u003ecount=%{value}\u003cextra\u003e\u003c\u002fextra\u003e","labels":["Africa","Asia","Central America","Europe","MENA","North America","South America"],"legendgroup":"","name":"","showlegend":true,"values":[2427,2353,363,3885,695,492,1155],"type":"pie"}],                        {"legend":{"tracegroupgap":0},"template":{"data":{"barpolar":[{"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"barpolar"}],"bar":[{"error_x":{"color":"#2a3f5f"},"error_y":{"color":"#2a3f5f"},"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"bar"}],"carpet":[{"aaxis":{"endlinecolor":"#2a3f5f","gridcolor":"white","linecolor":"white","minorgridcolor":"white","startlinecolor":"#2a3f5f"},"baxis":{"endlinecolor":"#2a3f5f","gridcolor":"white","linecolor":"white","minorgridcolor":"white","startlinecolor":"#2a3f5f"},"type":"carpet"}],"choropleth":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"choropleth"}],"contourcarpet":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"contourcarpet"}],"contour":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"contour"}],"heatmapgl":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"heatmapgl"}],"heatmap":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"heatmap"}],"histogram2dcontour":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"histogram2dcontour"}],"histogram2d":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"histogram2d"}],"histogram":[{"marker":{"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"histogram"}],"mesh3d":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"mesh3d"}],"parcoords":[{"line":{"colorbar":{"outlinewidth":0,"ticks":""}},"type":"parcoords"}],"pie":[{"automargin":true,"type":"pie"}],"scatter3d":[{"line":{"colorbar":{"outlinewidth":0,"ticks":""}},"marker":{"colorbar":{"outlinewidth":0,"ticks": ...
#
# v

# %%
df_Europe = df[df['region'] == 'Europe'].drop('region', axis=1)
df_Africa = df[df['region'] == 'Africa'].drop('region', axis=1)
df_Asia = df[df['region'] == 'Asia'].drop('region', axis=1)
df_North_America = df[df['region'] == 'North America'].drop('region', axis=1)
df_South_America = df[df['region'] == 'South America'].drop('region', axis=1)
df_Central_America = df[df['region'] == 'Central America'].drop('region', axis=1)
df_MENA = df[df['region'] == 'MENA'].drop('region', axis=1)

# %% [markdown]
# ## Europe analysis

# %%
df_Europe.head()
# Out:
#              Country  Year  protesterviolence             protesterdemand1  \
# 2167  United Kingdom  1990                  0           labor wage dispute
# 2168  United Kingdom  1990                  0  price increases, tax policy
# 2169  United Kingdom  1990                  0  political behavior, process
# 2170  United Kingdom  1990                  0  price increases, tax policy
# 2171  United Kingdom  1990                  0  price increases, tax policy
#
#        stateresponse1  Electoral_Score  Liberal_Score  Participatory_Score  \
# 2167           ignore            0.817          0.745                0.573
# 2168           ignore            0.817          0.745                0.573
# 2169  crowd dispersal            0.817          0.745                0.573
# 2170  crowd dispersal            0.817          0.745                0.573
# 2171  crowd dispersal            0.817          0.745                0.573
#
#       Deliberative_Score  Egalitarian_Score  HDI_Score  violenceStatus  \
# 2167               0.695              0.673      0.781               0
# 2168               0.695              0.673      0.781               0
# 2169               0.695              0.673      0.781               1
# 2170               0.695              0.673      0.781               1
# 2171               0.695              0.673      0.781               1
#
#       predicted_prob
# 2167        0.315732
# 2168        0.315732
# 2169        0.315732
# 2170        0.315732
# 2171        0.315732

# %%
df_Europe['protesterdemand1'].value_counts()
# Out:
# protesterdemand1
# political behavior, process    2534
# labor wage dispute              509
# price increases, tax policy     321
# removal of politician           173
# land farm issue                 117
# social restrictions             116
# police brutality                115
# Name: count, dtype: int64

# %%
df_Europe['stateresponse1'].value_counts()
# Out:
# stateresponse1
# ignore             2577
# crowd dispersal     871
# arrests             192
# accomodation        190
# beatings             39
# shootings            13
# killings              3
# Name: count, dtype: int64

# %%
fig = px.box(df_Europe, x='Country', y='Year', color='protesterviolence')
iplot(fig)
# Out:
# <div>                            <div id="5d64d1b9-0b5f-4be9-9b53-4e98951f77d6" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("5d64d1b9-0b5f-4be9-9b53-4e98951f77d6")) {                    Plotly.newPlot(                        "5d64d1b9-0b5f-4be9-9b53-4e98951f77d6",                        [{"alignmentgroup":"True","hovertemplate":"protesterviolence=0\u003cbr\u003eCountry=%{x}\u003cbr\u003eYear=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"0","marker":{"color":"#636efa"},"name":"0","notched":false,"offsetgroup":"0","orientation":"v","showlegend":true,"x":["United Kingdom","United Kingdom","United Kingdom","United Kingdom","United Kingdom","United Kingdom","United Kingdom","United Kingdom","United Kingdom","United Kingdom","United Kingdom","United Kingdom","United Kingdom","United Kingdom","United Kingdom","United Kingdom","United Kingdom","United Kingdom","United Kingdom","United Kingdom","United Kingdom","United Kingdom","United Kingdom","United Kingdom","United Kingdom","United Kingdom","United Kingdom","United Kingdom","United Kingdom","United Kingdom","United Kingdom","United Kingdom","United Kingdom","United Kingdom","United Kingdom","United Kingdom","United Kingdom","United Kingdom","United Kingdom","United Kingdom","United Kingdom","United Kingdom","United Kingdom","United Kingdom","United Kingdom","United Kingdom","United Kingdom","United Kingdom","United Kingdom","United Kingdom","United Kingdom","United Kingdom","United Kingdom","United Kingdom","United Kingdom","United Kingdom","United Kingdom","United Kingdom","United Kingdom","United Kingdom","United Kingdom","United Kingdom","United Kingdom","United Kingdom","United Kingdom","United Kingdom","United Kingdom","United Kingdom","United Kingdom","United Kingdom","United Kingdom","United Kingdom","United Kingdom","United Kingdom","United Kingdom","United Kingdom","United Kingdom","United Kingdom","United Kingdom","United Kingdom","United Kingdom","United Kingdom","United Kingdom","United Kingdom","United Kingdom","United Kingdom","United Kingdom","United Kingdom","United Kingdom","United Kingdom","United Kingdom","United Kingdom","United Kingdom","United Kingdom","United Kingdom","United Kingdom","United Kingdom","United Kingdom","United Kingdom","United Kingdom","United Kingdom","United Kingdom","United Kingdom","United Kingdom","United Kingdom","United Kingdom","United Kingdom","United Kingdom","United Kingdom","United Kingdom","United Kingdom","United Kingdom","United Kingdom","United Kingdom","United Kingdom","United Kingdom","United Kingdom","United Kingdom","United Kingdom","United Kingdom","United Kingdom","United Kingdom","United Kingdom","United Kingdom","United Kingdom","United Kingdom","United Kingdom","United Kingdom","United Kingdom","United Kingdom","United Kingdom","United Kingdom","United Kingdom","United Kingdom","United Kingdom","United Kingdom","United Kingdom","United Kingdom","United Kingdom","United Kingdom","United Kingdom","United Kingdom","United Kingdom","United Kingdom","United Kingdom","United Kingdom","United Kingdom","United Kingdom","United Kingdom","United Kingdom","United Kingdom","United Kingdom","United Kingdom","United Kingdom","United Kingdom","United Kingdom","United Kingdom","United Kingdom","United Kingdom","United Kingdom","United Kingdom","United Kingdom","United Kingdom","United Kingdom","United Kingdom","United Kingdom","United Kingdom","United Kingdom","United Kingdom","United Kingdom","United Kingdom","United Kingdom","United Kingdom","United Kingdom","United Kingdom","United Kingdom","United Kingdom","United Kingdom","United Kingdom","United Kingdom","United Kingdom","United Kingdom","United Kingdom","United Kingdom","United Kingdom","United Kingdom","United Kingdom","Unit ...

# %%
gr = df_Europe.groupby(['Country', 'Year'])['Country'].size().reset_index(name='cnt')
gr
# Out:
#             Country  Year  cnt
# 0           Albania  1990    5
# 1           Albania  1991    8
# 2           Albania  1992    3
# 3           Albania  1993    2
# 4           Albania  1994    1
# ..              ...   ...  ...
# 456  United Kingdom  2015   20
# 457  United Kingdom  2016   35
# 458  United Kingdom  2017   21
# 459  United Kingdom  2018   24
# 460  United Kingdom  2019   32
#
# [461 rows x 3 columns]

# %%
fig = px.line(gr, x='Year', y='cnt', animation_frame='Country', template='ggplot2')
y_min = gr['cnt'].min() - 1  
y_max = gr['cnt'].max() + 1 
x_min = gr['Year'].min()
x_max = gr['Year'].max() + 1
fig.update_yaxes(range=[y_min, y_max], title_text='Count', title_font=dict(size=14), gridcolor='LightGray')
fig.update_xaxes(range=[x_min, x_max], title_text='Year', title_font=dict(size=14), gridcolor='LightGray')
fig.update_layout(
    title_x=0.5,  
    width=1200,
    height=900,
    legend_title_text='Countries',
    hovermode='x unified'
)
iplot(fig)
# Out:
# <div>                            <div id="4f5f3166-c975-4400-a9bf-88fe06a34052" class="plotly-graph-div" style="height:900px; width:1200px;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("4f5f3166-c975-4400-a9bf-88fe06a34052")) {                    Plotly.newPlot(                        "4f5f3166-c975-4400-a9bf-88fe06a34052",                        [{"hovertemplate":"Country=Albania\u003cbr\u003eYear=%{x}\u003cbr\u003ecnt=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"","line":{"color":"#F8766D","dash":"solid"},"marker":{"symbol":"circle"},"mode":"lines","name":"","orientation":"v","showlegend":false,"x":[1990,1991,1992,1993,1994,1996,1997,1998,2000,2010,2011,2013,2017,2018,2019],"xaxis":"x","y":[5,8,3,2,1,1,11,3,1,6,3,3,2,11,17],"yaxis":"y","type":"scatter"}],                        {"height":900,"hovermode":"x unified","legend":{"title":{"text":"Countries"},"tracegroupgap":0},"margin":{"t":60},"sliders":[{"active":0,"currentvalue":{"prefix":"Country="},"len":0.9,"pad":{"b":10,"t":60},"steps":[{"args":[["Albania"],{"frame":{"duration":0,"redraw":false},"mode":"immediate","fromcurrent":true,"transition":{"duration":0,"easing":"linear"}}],"label":"Albania","method":"animate"},{"args":[["Armenia"],{"frame":{"duration":0,"redraw":false},"mode":"immediate","fromcurrent":true,"transition":{"duration":0,"easing":"linear"}}],"label":"Armenia","method":"animate"},{"args":[["Azerbaijan"],{"frame":{"duration":0,"redraw":false},"mode":"immediate","fromcurrent":true,"transition":{"duration":0,"easing":"linear"}}],"label":"Azerbaijan","method":"animate"},{"args":[["Belarus"],{"frame":{"duration":0,"redraw":false},"mode":"immediate","fromcurrent":true,"transition":{"duration":0,"easing":"linear"}}],"label":"Belarus","method":"animate"},{"args":[["Bulgaria"],{"frame":{"duration":0,"redraw":false},"mode":"immediate","fromcurrent":true,"transition":{"duration":0,"easing":"linear"}}],"label":"Bulgaria","method":"animate"},{"args":[["Cyprus"],{"frame":{"duration":0,"redraw":false},"mode":"immediate","fromcurrent":true,"transition":{"duration":0,"easing":"linear"}}],"label":"Cyprus","method":"animate"},{"args":[["France"],{"frame":{"duration":0,"redraw":false},"mode":"immediate","fromcurrent":true,"transition":{"duration":0,"easing":"linear"}}],"label":"France","method":"animate"},{"args":[["Georgia"],{"frame":{"duration":0,"redraw":false},"mode":"immediate","fromcurrent":true,"transition":{"duration":0,"easing":"linear"}}],"label":"Georgia","method":"animate"},{"args":[["Germany"],{"frame":{"duration":0,"redraw":false},"mode":"immediate","fromcurrent":true,"transition":{"duration":0,"easing":"linear"}}],"label":"Germany","method":"animate"},{"args":[["Greece"],{"frame":{"duration":0,"redraw":false},"mode":"immediate","fromcurrent":true,"transition":{"duration":0,"easing":"linear"}}],"label":"Greece","method":"animate"},{"args":[["Hungary"],{"frame":{"duration":0,"redraw":false},"mode":"immediate","fromcurrent":true,"transition":{"duration":0,"easing":"linear"}}],"label":"Hungary","method":"animate"},{"args":[["Ireland"],{"frame":{"duration":0,"redraw":false},"mode":"immediate","fromcurrent":true,"transition":{"duration":0,"easing":"linear"}}],"label":"Ireland","method":"animate"},{"args":[["Italy"],{"frame":{"duration":0,"redraw":false},"mode":"immediate","fromcurrent":true,"transition":{"duration":0,"easing":"linear"}}],"label":"Italy","method":"animate"},{"args":[["Latvia"],{"frame":{"duration":0,"redraw":false},"mode":"immediate","fromcurrent":true,"transition":{"duration":0,"easing":"linear"}}],"label":"Latvia","method":"animate"},{"args":[["Poland"],{"frame":{"duration":0,"redraw":false},"mode":"immediate","fromcurrent":true,"transition":{"duration":0,"easing":"linear"}}],"label":"Poland","method":"animate"},{"args":[["Romania"],{"frame":{"duration" ...
